# %%
import matplotlib.pyplot as plt
import numpy as np
import ticktack
from ticktack import fitting
import os
from matplotlib.lines import Line2D
import matplotlib as mpl
mpl.style.use('seaborn-colorblind')

# %%
# Out:
# INFO[2022-01-25 13:49:16,010]: Unable to initialize backend 'tpu_driver': Not found: Unable to find driver in registry given worker:
# INFO[2022-01-25 13:49:16,011]: Unable to initialize backend 'gpu': Not found: Could not find registered platform with name: "cuda". Available platform names are: Host Interpreter
# INFO[2022-01-25 13:49:16,012]: Unable to initialize backend 'tpu': Invalid argument: TpuPlatform is not available.
# WARNING[2022-01-25 13:49:16,013]: No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# WARNING[2022-01-25 13:50:12,225]: No handles with labels found to put in legend.
